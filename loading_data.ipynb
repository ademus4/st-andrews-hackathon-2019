# %%
import pandas as pd
import numpy as np
import altair as alt
from police_api import PoliceAPI

# %%
df_crimes = pd.read_csv('astraea/2018-01/2018-01-cleveland-outcomes.csv')
df_stop_search = pd.read_csv('astraea/2018-01/2018-01-cleveland-stop-and-search.csv')
df_street = pd.read_csv('astraea/2018-01/2018-01-cleveland-street.csv')

# %%
df_crimes.columns
# Out:
# Index(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Outcome type'],
#       dtype='object')

# %%
df_stop_search.columns
# Out:
# Index(['Type', 'Date', 'Part of a policing operation', 'Policing operation',
#        'Latitude', 'Longitude', 'Gender', 'Age range',
#        'Self-defined ethnicity', 'Officer-defined ethnicity', 'Legislation',
#        'Object of search', 'Outcome', 'Outcome linked to object of search',
#        'Removal of more than just outer clothing'],
#       dtype='object')

# %%
df_street.columns
# Out:
# Index(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type',
#        'Last outcome category', 'Context'],
#       dtype='object')

# %% [markdown]
# # Crime outcomes data

# %%
df_crimes.head()
# Out:
#                                             Crime ID    Month  \
# 0  ed86f3961fc14ba2bf68c5e890640f7956771fc6b43746...  2018-01
# 1  525586b474b63596fea4f4bc6840e46487e4618ada2d98...  2018-01
# 2  9bc80e722f86f02b9bec405f67f7fb2679178df1c194b1...  2018-01
# 3  14e07afc1aa889c30431de4ecb33abeef4dc5ff33bf798...  2018-01
# 4  bf38f3d44662c40b106bc0b483468aa502006aff92d38a...  2018-01
#
#         Reported by      Falls within  Longitude   Latitude  \
# 0  Cleveland Police  Cleveland Police  -1.312382  54.562567
# 1  Cleveland Police  Cleveland Police  -1.178931  54.564324
# 2  Cleveland Police  Cleveland Police  -1.215581  54.685298
# 3  Cleveland Police  Cleveland Police  -1.234467  54.657649
# 4  Cleveland Police  Cleveland Police  -1.140277  54.571209
#
#                    Location  LSOA code                  LSOA name  \
# 0  On or near Shopping Area  E01033477      Stockton-on-Tees 014G
# 1   On or near ANSDALE ROAD  E01012089         Middlesbrough 007D
# ...

# %% [markdown]
# ### Plotting example with Altair

# %%
alt.Chart(df_crimes[:4000]).mark_point().encode(
    x='LSOA name',
    y='Outcome type'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# # Stop and s

# %%
df_stop_search.head()
# Out:
#                         Type                       Date  \
# 0              Person search  2018-01-01T00:45:00+00:00
# 1              Person search  2018-01-01T00:45:00+00:00
# 2  Person and Vehicle search  2018-01-01T01:40:00+00:00
# 3              Person search  2018-01-02T17:05:00+00:00
# 4             Vehicle search  2018-01-02T18:00:00+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           NaN                 NaN  54.524297  -1.311758
# 1                           NaN                 NaN  54.524297  -1.311758
# 2                           NaN                 NaN        NaN        NaN
# 3                           NaN                 NaN        NaN        NaN
# 4                           NaN                 NaN        NaN        NaN
#
#   Gender Age range                             Self-defined ethnicity  \
# 0   Male     25-34                                                NaN
# ...

# %% [markdown]
# # Street crimes data

# %%
df_street.head()
# Out:
#   Crime ID    Month       Reported by      Falls within  Longitude   Latitude  \
# 0      NaN  2018-01  Cleveland Police  Cleveland Police  -1.235446  54.711190
# 1      NaN  2018-01  Cleveland Police  Cleveland Police  -1.239958  54.710607
# 2      NaN  2018-01  Cleveland Police  Cleveland Police  -1.238644  54.709494
# 3      NaN  2018-01  Cleveland Police  Cleveland Police  -1.235446  54.711190
# 4      NaN  2018-01  Cleveland Police  Cleveland Police  -1.238644  54.709494
#
#                      Location  LSOA code        LSOA name  \
# 0  On or near King Oswy Drive  E01011954  Hartlepool 001A
# 1   On or near Marshall Close  E01011954  Hartlepool 001A
# 2     On or near Whin Meadows  E01011954  Hartlepool 001A
# 3  On or near King Oswy Drive  E01011954  Hartlepool 001A
# 4     On or near Whin Meadows  E01011954  Hartlepool 001A
#
#               Crime type Last outcome category  Context
# 0  Anti-social behaviour                   NaN      NaN
# ...

# %% [markdown]
# # Querying the API for the same data

# %%
api = PoliceAPI()
api.get_forces()
# Out:
# [<Force> Avon and Somerset Constabulary,
#  <Force> Bedfordshire Police,
#  <Force> Cambridgeshire Constabulary,
#  <Force> Cheshire Constabulary,
#  <Force> City of London Police,
#  <Force> Cleveland Police,
#  <Force> Cumbria Constabulary,
#  <Force> Derbyshire Constabulary,
#  <Force> Devon & Cornwall Police,
#  <Force> Dorset Police,
#  <Force> Durham Constabulary,
#  <Force> Dyfed-Powys Police,
#  <Force> Essex Police,
#  <Force> Gloucestershire Constabulary,
#  <Force> Greater Manchester Police,
#  <Force> Gwent Police,
#  <Force> Hampshire Constabulary,
#  <Force> Hertfordshire Constabulary,
#  <Force> Humberside Police,
#  <Force> Kent Police,
#  <Force> Lancashire Constabulary,
#  <Force> Leicestershire Police,
#  <Force> Lincolnshire Police,
#  <Force> Merseyside Police,
#  <Force> Metropolitan Police Service,
#  <Force> Norfolk Constabulary,
#  <Force> North Wales Police,
#  <Force> North Yorkshire Police,
#  <Force> Northamptonshire Police,
# ...
